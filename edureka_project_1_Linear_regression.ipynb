# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score
data = pd.read_csv("headbrain.csv")

print(data.shape)
data.head()
# Out:
# (237, 4)
#    Gender  Age Range  Head Size(cm^3)  Brain Weight(grams)
# 0       1          1             4512                 1530
# 1       1          1             3738                 1297
# 2       1          1             4261                 1335
# 3       1          1             3777                 1282
# 4       1          1             4177                 1590

# %%
#Collecting X and Y 
X = data['Head Size(cm^3)']
Y = data['Brain Weight(grams)']

# %%
mean_x = np.mean(X)
mean_y = np.mean(Y)
#Total no. of val
n = len(X)
numer = 0
denom = 0
for i in range(n):
    numer += (X[i]-mean_x)*(Y[i]-mean_y)
    denom += (X[i]-mean_x)**2
m=numer/denom
c=mean_y - (mean_x*m)
m,y
# Out:
# (0.26342933948939945,
#  array([1602.41542955, 1590.44283488, 1578.47024021, 1566.49764553,
#         1554.52505086, 1542.55245618, 1530.57986151, 1518.60726683,
#         1506.63467216, 1494.66207749, 1482.68948281, 1470.71688814,
#         1458.74429346, 1446.77169879, 1434.79910411, 1422.82650944,
#         1410.85391477, 1398.88132009, 1386.90872542, 1374.93613074,
#         1362.96353607, 1350.99094139, 1339.01834672, 1327.04575204,
#         1315.07315737, 1303.1005627 , 1291.12796802, 1279.15537335,
#         1267.18277867, 1255.210184  , 1243.23758932, 1231.26499465,
#         1219.29239998, 1207.3198053 , 1195.34721063, 1183.37461595,
#         1171.40202128, 1159.4294266 , 1147.45683193, 1135.48423726,
#         1123.51164258, 1111.53904791, 1099.56645323, 1087.59385856,
#         1075.62126388, 1063.64866921, 1051.67607453, 1039.70347986,
#         1027.73088519, 1015.75829051]))

# %%
plt.scatter(X,Y)
plt.plot()
# Out:
# []

# %%
x=np.linspace(np.max(X),np.min(X))
y=m*x+c
plt.plot(x,y)
plt.scatter(X,Y,color="pink")
